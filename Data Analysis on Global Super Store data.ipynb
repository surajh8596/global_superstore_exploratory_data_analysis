# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
global_store=pd.read_excel('D:\\PGP IN DATA SCIENCE with careerera\\Files\\Global_Superstore.xlsx')

# %%
global_store.head(4)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
#
#    ... Sub-Category                               Product Name     Sales  \
# 0  ...       Phones                           Samsung Convoy 3   221.980
# 1  ...       Chairs  Novimex Executive Leather Armchair, Black  3709.395
# ...

# %%
store=pd.read_excel('D:\\PGP IN DATA SCIENCE with careerera\\Files\\Global_Superstore.xlsx')

# %%
store.head(4)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
#
#    ... Sub-Category                               Product Name     Sales  \
# 0  ...       Phones                           Samsung Convoy 3   221.980
# 1  ...       Chairs  Novimex Executive Leather Armchair, Black  3709.395
# ...

# %%
store1=pd.read_excel('D:\\PGP IN DATA SCIENCE\\Files\\Global_Superstore.xlsx', sheet_name=1)

# %%
store1
# Out:
#               Unnamed: 0         Unnamed: 1
# 0                 Person             Region
# 1      Marilène Rousseau          Caribbean
# 2       Andile Ihejirika     Central Africa
# 3      Nicodemo Bautista    Central America
# 4         Cansu Peynirci       Central Asia
# 5             Lon Bonher         Central US
# 6           Wasswa Ahmed     Eastern Africa
# 7          Hadia Bousaid       Eastern Asia
# 8         Lynne Marchand     Eastern Canada
# 9          Oxana Lagunov     Eastern Europe
# 10         Dolores Davis         Eastern US
# 11      Lindiwe Afolayan       North Africa
# 12          Miina Nylund    Northern Europe
# 13           Kauri Anaru            Oceania
# 14       Vasco Magalhães      South America
# 15      Preecha Metharom  Southeastern Asia
# 16          Nora Cuijper    Southern Africa
# 17  Chandrakant Chaudhri      Southern Asia
# 18           Gavino Bove    Southern Europe
# 19       Flannery Newton        Southern US
# ...

# %%
store1=pd.read_excel('D:\\PGP IN DATA SCIENCE\\Files\\Global_Superstore.xlsx', sheet_name='People')

# %%
store1
# Out:
#               Unnamed: 0         Unnamed: 1
# 0                 Person             Region
# 1      Marilène Rousseau          Caribbean
# 2       Andile Ihejirika     Central Africa
# 3      Nicodemo Bautista    Central America
# 4         Cansu Peynirci       Central Asia
# 5             Lon Bonher         Central US
# 6           Wasswa Ahmed     Eastern Africa
# 7          Hadia Bousaid       Eastern Asia
# 8         Lynne Marchand     Eastern Canada
# 9          Oxana Lagunov     Eastern Europe
# 10         Dolores Davis         Eastern US
# 11      Lindiwe Afolayan       North Africa
# 12          Miina Nylund    Northern Europe
# 13           Kauri Anaru            Oceania
# 14       Vasco Magalhães      South America
# 15      Preecha Metharom  Southeastern Asia
# 16          Nora Cuijper    Southern Africa
# 17  Chandrakant Chaudhri      Southern Asia
# 18           Gavino Bove    Southern Europe
# 19       Flannery Newton        Southern US
# ...

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Row ID                   51290 non-null  int64
#  1   Order ID                 51290 non-null  object
#  2   Order Date               51290 non-null  datetime64[ns]
#  3   Ship Date                51290 non-null  datetime64[ns]
#  4   Ship Mode                51290 non-null  object
#  5   Customer ID              51290 non-null  object
#  6   Customer Name            51290 non-null  object
#  7   Segment                  51290 non-null  object
#  8   Postal Code              9994 non-null   float64
#  9   City                     51290 non-null  object
#  10  State                    51290 non-null  object
#  11  Country                  51290 non-null  object
#  12  Region                   51290 non-null  object
# ...

# %%
store.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.478567
# std      174.340972      57.251373
# min    -6599.978000       1.002000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
store.describe(include='O')
# Out:
#                         Order ID       Ship Mode   Customer ID  \
# count                      51290           51290         51290
# unique                     25728               4         17415
# top     CA-2015-SV20365140-42268  Standard Class  SV-203651406
# freq                          14           30775            26
#
#           Customer Name   Segment           City       State        Country  \
# count             51290     51290          51290       51290          51290
# unique              796         3           3650        1102            165
# top     Muhammed Yedwab  Consumer  New York City  California  United States
# freq                108     26518            915        2001           9994
#
#                 Region        Market   Product ID         Category  \
# count            51290         51290        51290            51290
# unique              23             5         3788                3
# ...

# %%
##Dleting columns---1)deleting column-'Postal Code'--- which has multiple null values

# %%
store.drop(['Postal Code'], axis=1,inplace=True)

# %%
store.head(4)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
#
#     Customer ID     Customer Name      Segment           City  \
# 0  AB-100151402     Aaron Bergman     Consumer  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate     Wollongong
# 2     CR-127307      Craig Reiter     Consumer       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         Berlin
#
#              State  ... Sub-Category  \
# 0         Oklahoma  ...       Phones
# 1  New South Wales  ...       Chairs
# 2       Queensland  ...       Phones
# 3           Berlin  ...       Phones
#
#                                 Product Name     Sales Quantity Discount  \
# ...

# %%
##groupby to check different dates on which order placed

# %%
store.groupby('Order Date').mean()
# Out:
#                   Row ID       Sales  Quantity  Discount      Profit  \
# Order Date
# 2012-01-01  28301.500000  134.760500  3.166667  0.133333   33.145500
# 2012-01-02  49550.000000  314.220000  1.000000  0.000000    3.120000
# 2012-01-03  32296.200000  225.176860  2.400000  0.186000    9.229860
# 2012-01-04  16671.000000  175.554390  3.250000  0.112625   39.695215
# 2012-01-05  23802.857143  523.187143  3.428571  0.171429  150.481414
# ...                  ...         ...       ...       ...         ...
# 2015-12-27  22905.944444  248.541921  3.481481  0.208593  -16.974816
# 2015-12-28  23401.000000  126.705692  3.923077  0.084615    6.235677
# 2015-12-29  24990.112069  216.459386  3.517241  0.173983   17.639714
# 2015-12-30  27558.898734  213.058415  3.594937  0.163544   32.329172
# 2015-12-31  22607.725806  213.837973  3.596774  0.104065   16.454368
#
#             Shipping Cost
# Order Date
# 2012-01-01      10.778333
# 2012-01-02      24.100000
# 2012-01-03      23.671050
# ...

# %%
store.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Region', 'Market', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Profit Category-Updated', 'Profit Category', 'Shipping Cost',
#        'Order Priority'],
#       dtype='object')

# %%
import datetime as dt

# %%
store['Month']=store['Order Date'].dt.month

# %%
store.head(4)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
#
#     Customer ID     Customer Name      Segment           City  \
# 0  AB-100151402     Aaron Bergman     Consumer  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate     Wollongong
# 2     CR-127307      Craig Reiter     Consumer       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         Berlin
#
#              State  ...                               Product Name     Sales  \
# 0         Oklahoma  ...                           Samsung Convoy 3   221.980
# 1  New South Wales  ...  Novimex Executive Leather Armchair, Black  3709.395
# ...

# %%
store.rename({'Month':'Order_Month'},axis=1,inplace=True)

# %%
store.head(4)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
#
#     Customer ID     Customer Name      Segment           City  \
# 0  AB-100151402     Aaron Bergman     Consumer  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate     Wollongong
# 2     CR-127307      Craig Reiter     Consumer       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         Berlin
#
#              State  ...                               Product Name     Sales  \
# 0         Oklahoma  ...                           Samsung Convoy 3   221.980
# 1  New South Wales  ...  Novimex Executive Leather Armchair, Black  3709.395
# ...

# %%
store['Order_Year']=store['Order Date'].dt.year

# %%
store['Ship_month']=store['Ship Date'].dt.month

# %%
store['Ship_Year']=store['Ship Date'].dt.year

# %%
store.head(4)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
#
#     Customer ID     Customer Name      Segment           City  \
# 0  AB-100151402     Aaron Bergman     Consumer  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate     Wollongong
# 2     CR-127307      Craig Reiter     Consumer       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         Berlin
#
#              State  ... Discount    Profit Profit Category-Updated  \
# 0         Oklahoma  ...      0.0   62.1544                   Worse
# 1  New South Wales  ...      0.1 -288.7650                   Worse
# 2       Queensland  ...      0.1  919.9710                   Worse
# ...

# %%
## To know unique values

# %%
store.Order_Year.nunique()
# Out:
# 4

# %%
store.Ship_Year.nunique()
# Out:
# 5

# %%
store.Order_Year.unique()
# Out:
# array([2014, 2012, 2013, 2015], dtype=int64)

# %%
store.Ship_Year.unique()
# Out:
# array([2014, 2012, 2013, 2015, 2016], dtype=int64)

# %%
store.rename({'Ship Mode':'Ship_Mode'},axis=1,inplace=True)

# %%
store.Ship_Mode.nunique()
# Out:
# 4

# %%
store.Ship_Mode.unique()
# Out:
# array(['First Class', 'Second Class', 'Same Day', 'Standard Class'],
#       dtype=object)

# %%
store.Segment.nunique()
# Out:
# 3

# %%
store.Segment.unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
store.Region.unique()
# Out:
# array(['Central US', 'Oceania', 'Western Europe', 'Western Africa',
#        'Western US', 'Southern Asia', 'Western Asia', 'South America',
#        'Eastern Asia', 'Southern Europe', 'Eastern Africa',
#        'Eastern Europe', 'Northern Europe', 'Central America',
#        'Eastern US', 'Caribbean', 'Central Africa', 'Southeastern Asia',
#        'Southern US', 'North Africa', 'Southern Africa', 'Canada',
#        'Central Asia'], dtype=object)

# %%
store.Market.unique()
# Out:
# array(['USCA', 'Asia Pacific', 'Europe', 'Africa', 'LATAM'], dtype=object)

# %%
store.Category.unique()
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %%
store.rename({'Sub-Category':'Sub_Category'},axis=1,inplace=True)

# %%
store.Sub_Category.unique()
# Out:
# array(['Phones', 'Chairs', 'Copiers', 'Tables', 'Bookcases', 'Art',
#        'Appliances', 'Storage', 'Fasteners', 'Machines', 'Accessories',
#        'Furnishings', 'Binders', 'Labels', 'Paper', 'Supplies',
#        'Envelopes'], dtype=object)

# %%
store.value_counts('Sub_Category')
# Out:
# Sub_Category
# Binders        6146
# Storage        5049
# Art            4864
# Paper          3492
# Chairs         3434
# Phones         3357
# Furnishings    3154
# Accessories    3075
# Labels         2601
# Fasteners      2601
# Bookcases      2411
# Supplies       2407
# Envelopes      2387
# Copiers        2223
# Appliances     1742
# Machines       1486
# Tables          861
# dtype: int64

# %%
plt.figure(figsize=(5,8))
sns.countplot(y='Sub_Category', data=store);

# %%
store.value_counts('Product Name')
# Out:
# Product Name
# Staples                                                                      227
# Cardinal Index Tab, Clear                                                     92
# Eldon File Cart, Single Width                                                 90
# Rogers File Cart, Single Width                                                84
# Ibico Index Tab, Clear                                                        83
#                                                                             ...
# Fellowes Smart Surge Ten-Outlet Protector, Platinum                            1
# RCA H5401RE1 DECT 6.0 4-Line Cordless Handset With Caller ID/Call Waiting      1
# RCA ViSYS 25423RE1 Corded phone                                                1
# RCA ViSYS 25425RE1 Corded phone                                                1
# Pyle PRT45 Retro Home Telephone                                                1
# Length: 3788, dtype: int64

# %%
# understanding which shipping method is most prefered

# %%
store.value_counts('Ship_Mode')
# Out:
# Ship_Mode
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# dtype: int64

# %%
sns.countplot(y='Ship_Mode', data=store);

# %%
store.Ship_Mode.value_counts()
# Out:
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: Ship_Mode, dtype: int64

# %%
## which Category has highest sale

# %%
pd.pivot_table(store, values='Sales',index=['Category'], aggfunc=sum)
# Out:
#                         Sales
# Category
# Furniture        4.110452e+06
# Office Supplies  3.787493e+06
# Technology       4.744557e+06

# %%
sns.barplot(x='Category', y='Sales', data=store);

# %%
pd.pivot_table(store, values='Sales', index=['Category','Sub_Category'],aggfunc=sum)
# Out:
#                                      Sales
# Category        Sub_Category
# Furniture       Bookcases     1.466572e+06
#                 Chairs        1.501682e+06
#                 Furnishings   3.851560e+05
#                 Tables        7.570419e+05
# Office Supplies Appliances    1.010536e+06
#                 Art           3.716132e+05
#                 Binders       4.618694e+05
#                 Envelopes     1.692175e+05
#                 Fasteners     8.949505e+04
#                 Labels        7.335028e+04
#                 Paper         2.417875e+05
#                 Storage       1.126813e+06
#                 Supplies      2.428111e+05
# Technology      Accessories   7.492370e+05
#                 Copiers       1.509436e+06
#                 Machines      7.790601e+05
#                 Phones        1.706824e+06

# %%
plt.figure(figsize=(5,5))
sns.barplot(y='Sub_Category', x='Sales', hue='Category', data=store);

# %%
## which market place have more sale

# %%
pd.pivot_table(store,values='Sales', index='Market', aggfunc=sum)
# Out:
#                      Sales
# Market
# Africa        7.837732e+05
# Asia Pacific  4.042658e+06
# Europe        3.287336e+06
# LATAM         2.164605e+06
# USCA          2.364129e+06

# %%
sns.barplot(y='Market', x='Sales', data=store);

# %%
## which Country has more sales

# %%
pd.pivot_table(store, values='Sales', index='Country', aggfunc=sum)
# Out:
#                       Sales
# Country
# Afghanistan     21673.32000
# Albania          3888.12000
# Algeria         36091.59000
# Angola          25554.00000
# Argentina       57511.78328
# ...                     ...
# Vietnam         65210.06580
# Western Sahara    666.36000
# Yemen            2465.71200
# Zambia          26035.50000
# Zimbabwe         3765.10500
#
# [165 rows x 1 columns]

# %%
store['Country']
# Out:
# 0        United States
# 1            Australia
# 2            Australia
# 3              Germany
# 4              Senegal
#              ...
# 51285            Japan
# 51286    United States
# 51287    United States
# 51288           Brazil
# 51289        Nicaragua
# Name: Country, Length: 51290, dtype: object

# %%
store.Country.nunique()
# Out:
# 165

# %%
pd.pivot_table(store, values='Sales', index='Region',aggfunc=sum)
# Out:
#                           Sales
# Region
# Canada             6.692817e+04
# Caribbean          3.242809e+05
# Central Africa     1.436300e+05
# Central America    1.223101e+06
# Central Asia       1.931146e+04
# Central US         5.012399e+05
# Eastern Africa     1.278560e+05
# Eastern Asia       8.550594e+05
# Eastern Europe     3.100334e+05
# Eastern US         6.787812e+05
# North Africa       2.332166e+05
# Northern Europe    6.367792e+05
# Oceania            1.100185e+06
# South America      6.172237e+05
# Southeastern Asia  8.844232e+05
# Southern Africa    1.051918e+05
# Southern Asia      8.665727e+05
# Southern Europe    6.085940e+05
# Southern US        3.917219e+05
# Western Africa     1.738788e+05
# Western Asia       3.171070e+05
# Western Europe     1.731930e+06
# Western US         7.254578e+05

# %%
plt.figure(figsize=(5,8))
sns.barplot(x='Sales', y='Region', data=store);

# %%
## which ship mode has collected most shipping charges in total

# %%
pd.pivot_table(store, values='Shipping Cost', index='Ship_Mode', aggfunc=sum)
# Out:
#                 Shipping Cost
# Ship_Mode
# First Class      308585.54154
# Same Day         116140.71600
# Second Class     315009.79036
# Standard Class   618349.65550

# %%
sns.barplot(x='Ship_Mode', y='Shipping Cost', data=store);

# %%
## maximum and minimum shipping cost

# %%
pd.pivot_table(store, values='Shipping Cost', index='Ship_Mode', aggfunc=max)
# Out:
#                 Shipping Cost
# Ship_Mode
# First Class            915.49
# Same Day               933.57
# Second Class           923.63
# Standard Class         878.38

# %%
pd.pivot_table(store, values='Shipping Cost', index='Ship_Mode', aggfunc=min)
# Out:
#                 Shipping Cost
# Ship_Mode
# First Class             1.010
# Same Day                1.010
# Second Class            1.002
# Standard Class          1.003

# %%
## which product category is ordered most of time

# %%
pd.pivot_table(store, values='Quantity', index='Category', aggfunc=sum)
# Out:
#                  Quantity
# Category
# Furniture           34892
# Office Supplies    108244
# Technology          35176

# %%
sns.barplot(x='Category', y='Quantity', data=store);

# %%
pd.pivot_table(store, values='Quantity', index=['Category','Sub_Category'], aggfunc=sum)
# Out:
#                               Quantity
# Category        Sub_Category
# Furniture       Bookcases         8310
#                 Chairs           12336
#                 Furnishings      11163
#                 Tables            3083
# Office Supplies Appliances        6026
#                 Art              16215
#                 Binders          21403
#                 Envelopes         8210
#                 Fasteners         9051
#                 Labels            9301
#                 Paper            12672
#                 Storage          16884
#                 Supplies          8482
# Technology      Accessories      10946
#                 Copiers           7454
#                 Machines          4906
#                 Phones           11870

# %%
plt.figure(figsize=(5,8))
sns.barplot(y='Sub_Category', x='Quantity', hue='Category', data=store);

# %%
## on which year the sale is highest

# %%
pd.pivot_table(store, values='Sales', index='Order_Year', aggfunc=sum)
# Out:
#                    Sales
# Order_Year
# 2012        2.259451e+06
# 2013        2.677439e+06
# 2014        3.405746e+06
# 2015        4.299866e+06

# %%
sns.barplot(x='Order_Year', y='Sales', data=store);

# %%
## understanding year wise sales of category

# %%
pd.pivot_table(store, values='Sales', index=['Order_Year','Category'], aggfunc=sum)
# Out:
#                                    Sales
# Order_Year Category
# 2012       Furniture        7.560842e+05
#            Office Supplies  6.757146e+05
#            Technology       8.276521e+05
# 2013       Furniture        8.588218e+05
#            Office Supplies  7.951754e+05
#            Technology       1.023442e+06
# 2014       Furniture        1.117629e+06
#            Office Supplies  1.010812e+06
#            Technology       1.277305e+06
# 2015       Furniture        1.377917e+06
#            Office Supplies  1.305790e+06
#            Technology       1.616159e+06

# %%
sns.barplot(x='Sales', y='Category', hue='Order_Year', data=store);

# %%
pd.pivot_table(store, values='Sales', index=['Order_Year','Category','Sub_Category'], aggfunc=sum)
# Out:
#                                                 Sales
# Order_Year Category        Sub_Category
# 2012       Furniture       Bookcases     259396.28580
#                            Chairs        285730.97610
#                            Furnishings    63825.46040
#                            Tables        147131.49370
#            Office Supplies Appliances    173290.22240
# ...                                               ...
# 2015       Office Supplies Supplies       86177.26780
#            Technology      Accessories   253488.16360
#                            Copiers       550384.89376
#                            Machines      260279.23590
#                            Phones        552006.38010
#
# [68 rows x 1 columns]

# %%
sns.barplot(x='Sales', y='Sub_Category', hue='Order_Year', data=store);

# %%
## year wise profit

# %%
pd.pivot_table(store, values='Profit', index='Order_Year', aggfunc=sum)
# Out:
#                   Profit
# Order_Year
# 2012        248940.81154
# 2013        307415.27910
# 2014        406935.23018
# 2015        504165.97046

# %%
sns.barplot(x='Order_Year', y='Profit', data=store);

# %%
pd.pivot_table(store, values='Profit', index=['Order_Year','Category'], aggfunc=sum)
# Out:
#                                   Profit
# Order_Year Category
# 2012       Furniture         53654.68160
#            Office Supplies   86038.77910
#            Technology       109247.35084
# 2013       Furniture         58116.03560
#            Office Supplies  103322.30620
#            Technology       145976.93730
# 2014       Furniture         84047.19810
#            Office Supplies  149261.43820
#            Technology       173626.59388
# 2015       Furniture         89264.81490
#            Office Supplies  179973.30440
#            Technology       234927.85116

# %%
sns.barplot(x='Profit', y='Category', hue='Order_Year', data=store);

# %%
pd.pivot_table(store, values='Profit', index=['Order_Year','Category','Sub_Category'], aggfunc=sum)
# Out:
#                                                Profit
# Order_Year Category        Sub_Category
# 2012       Furniture       Bookcases      27518.85750
#                            Chairs         29943.15710
#                            Furnishings     7267.96150
#                            Tables        -11075.29450
#            Office Supplies Appliances     22820.26670
# ...                                               ...
# 2015       Office Supplies Supplies        7355.16960
#            Technology      Accessories    41593.92860
#                            Copiers       104048.53596
#                            Machines       18627.74530
#                            Phones         70657.64130
#
# [68 rows x 1 columns]

# %%
## Region wise profit

# %%
pd.pivot_table(store, values='Profit', index='Region', aggfunc=sum)
# Out:
#                          Profit
# Region
# Canada              17817.39000
# Caribbean           34571.32104
# Central Africa      35383.71000
# Central America    158981.64816
# Central Asia        -7282.01100
# Central US          39706.36250
# Eastern Africa      21900.90900
# Eastern Asia       167101.85100
# Eastern Europe      77084.88000
# Eastern US          91522.78000
# North Africa        57836.25000
# Northern Europe     83923.91700
# Oceania            120089.11200
# South America       28090.51788
# Southeastern Asia   17852.32900
# Southern Africa     24158.55000
# Southern Asia      159336.42700
# Southern Europe     70109.41800
# Southern US         46749.43030
# Western Africa     -50407.78800
# Western Asia       -53921.67000
# Western Europe     218433.50850
# Western US         108418.44890

# %%
sns.barplot(x='Region', y='Profit', data=store);

# %%
## Segment wise prifit

# %%
pd.pivot_table(store, values='Profit', index='Segment', aggfunc=sum)
# Out:
#                    Profit
# Segment
# Consumer     749239.78206
# Corporate    441208.32866
# Home Office  277009.18056

# %%
sns.barplot(x='Segment', y='Profit', data=store);

# %%
## understanging which market place have more profit

# %%
pd.pivot_table(store, values='Profit', index='Market', aggfunc=sum)
# Out:
#                     Profit
# Market
# Africa         88871.63100
# Asia Pacific  403176.03800
# Europe        449551.72350
# LATAM         221643.48708
# USCA          304214.41170

# %%
sns.barplot(x='Market', y='Profit',  data=store);

# %%
## country wise profit

# %%
pd.pivot_table(store, values='Profit', index='Country', aggfunc=sum)
# Out:
#                      Profit
# Country
# Afghanistan      5460.30000
# Albania           709.32000
# Algeria          9106.50000
# Angola           6494.97000
# Argentina      -18693.79672
# ...                     ...
# Vietnam         -1697.31420
# Western Sahara    300.42000
# Yemen           -3706.45800
# Zambia           7001.73000
# Zimbabwe        -5428.78500
#
# [165 rows x 1 columns]

# %%
## how many phones sold, profit

# %%
store_phones=store[store['Sub_Category']=='Phones']

# %%
store_phones
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship_Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# 12      45794   SA-2012-MM7260110-41269 2012-12-26 2012-12-28    Second Class
# ...       ...                       ...        ...        ...             ...
# 51200   32343  CA-2014-ZC21910140-41707 2014-03-09 2014-03-14  Standard Class
# 51216   31885  US-2014-ZC21910140-41719 2014-03-21 2014-03-25  Standard Class
# 51261   35111  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09        Same Day
# 51262   31316  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51265   37195  CA-2014-ZD21925140-41733 2014-04-04 2014-04-10  Standard Class
#
# ...

# %%
store_phones.value_counts('Sub_Category')
# Out:
# Sub_Category
# Phones    3357
# dtype: int64

# %%
pd.pivot_table(store_phones, values=['Sales','Profit','Quantity'], index=['Sub_Category','Order_Year'], aggfunc=sum)
# Out:
#                              Profit  Quantity        Sales
# Sub_Category Order_Year
# Phones       2012        53927.4895      2244  337282.4802
#              2013        45223.0498      2545  364016.2744
#              2014        46908.8252      3145  453519.0045
#              2015        70657.6413      3936  552006.3801

# %%
## How many  tables sold, their sales and profit

# %%
store_tables=store[store['Sub_Category']=='Tables']

# %%
store_tables
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship_Mode  \
# 7       31192   IN-2013-MB1808592-41378 2013-04-14 2013-04-18  Standard Class
# 11      28879    ID-2013-AJ107801-41383 2013-04-19 2013-04-22     First Class
# 20      46630    PL-2013-AB600103-41494 2013-08-08 2013-08-10     First Class
# 25       3484   MX-2015-VD2167039-42252 2015-09-05 2015-09-08     First Class
# 26      30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# ...       ...                       ...        ...        ...             ...
# 50917   38354  CA-2014-WB21850140-41985 2014-12-12 2014-12-12        Same Day
# 50964   35606  CA-2012-WB21850140-41216 2012-11-03 2012-11-10  Standard Class
# 51141   38121  CA-2013-YS21880140-41480 2013-07-25 2013-07-29  Standard Class
# 51192   32107  CA-2012-ZC21910140-41194 2012-10-12 2012-10-14     First Class
# 51195   33366  CA-2013-ZC21910140-41377 2013-04-13 2013-04-19  Standard Class
#
# ...

# %%
store_tables.value_counts('Sub_Category')
# Out:
# Sub_Category
# Tables    861
# dtype: int64

# %%
pd.pivot_table(store_tables, values=['Quantity','Sales','Profit'], index=['Order_Year','Sub_Category'], aggfunc=sum)
# Out:
#                              Profit  Quantity        Sales
# Order_Year Sub_Category
# 2012       Tables       -11075.2945       610  147131.4937
# 2013       Tables        -8421.6986       627  164086.4968
# 2014       Tables       -14040.4872       819  202363.5351
# 2015       Tables       -30545.9084      1027  243460.3988

# %%
## such manner we can find sales of any product ##

# %%
## finding sales in INDIA

# %%
sales_india=store[(store['Country']=='India')]

# %%
sales_india
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship_Mode  \
# 29      22999  IN-2013-BP1123058-41329 2013-02-24 2013-02-24        Same Day
# 41      29272  IN-2015-BF1100558-42319 2015-11-11 2015-11-15  Standard Class
# 42      25795  IN-2015-VG2180558-42273 2015-09-26 2015-09-28    Second Class
# 48      28701  IN-2015-SW2027558-42125 2015-05-01 2015-05-01        Same Day
# 55      29047  IN-2013-SG2047058-41424 2013-05-30 2013-05-31     First Class
# ...       ...                      ...        ...        ...             ...
# 51003   25350  IN-2012-SC2077058-41256 2012-12-13 2012-12-16    Second Class
# 51172   29523  IN-2014-AS1013558-41817 2014-06-27 2014-07-03  Standard Class
# 51176   23844  IN-2013-AR1057058-41441 2013-06-16 2013-06-21  Standard Class
# 51178   28694  IN-2015-AF1087058-42111 2015-04-17 2015-04-22  Standard Class
# 51283   24105  IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
#
# ...

# %%
pd.pivot_table(sales_india, values='Sales', index='Country', aggfunc=sum)
# Out:
#               Sales
# Country
# India    589486.035

# %%
## which sipping method is most preffered in india

# %%
sales_india.value_counts('Ship_Mode')
# Out:
# Ship_Mode
# Standard Class    972
# Second Class      330
# First Class       187
# Same Day           65
# dtype: int64

# %%
pd.pivot_table(sales_india, values='Shipping Cost', index='Country', aggfunc=sum)
# Out:
#          Shipping Cost
# Country
# India         61840.43

# %%
## maximum and minimum shipping cost

# %%
pd.pivot_table(sales_india, values='Shipping Cost', index='Country', aggfunc=max)
# Out:
#          Shipping Cost
# Country
# India           704.08

# %%
pd.pivot_table(sales_india, values='Shipping Cost', index='Country', aggfunc=min)
# Out:
#          Shipping Cost
# Country
# India             1.01

# %%
## profit in india

# %%
pd.pivot_table(sales_india, values='Profit', index='Country', aggfunc=sum)
# Out:
#              Profit
# Country
# India    129050.595

# %%
sales_india.value_counts('Segment')
# Out:
# Segment
# Consumer       816
# Corporate      430
# Home Office    308
# dtype: int64

# %%
sales_india.value_counts('Category')
# Out:
# Category
# Office Supplies    840
# Furniture          360
# Technology         354
# dtype: int64

# %%
sales_india.value_counts('Sub_Category')
# Out:
# Sub_Category
# Binders        146
# Chairs         139
# Phones         119
# Storage        107
# Paper          105
# Accessories    102
# Furnishings     99
# Bookcases       98
# Labels          94
# Fasteners       93
# Envelopes       91
# Supplies        86
# Copiers         84
# Art             76
# Machines        49
# Appliances      42
# Tables          24
# dtype: int64

# %%
## year wise sales in india

# %%
pd.pivot_table(sales_india, values='Sales', index='Order_Year', aggfunc=sum)
# Out:
#                  Sales
# Order_Year
# 2012         91396.005
# 2013        141328.965
# 2014        151729.080
# 2015        205031.985

# %%
pd.pivot_table(sales_india, values='Sales', index=['Order_Year','Category'], aggfunc=sum)
# Out:
#                                 Sales
# Order_Year Category
# 2012       Furniture        33366.795
#            Office Supplies  17557.425
#            Technology       40471.785
# 2013       Furniture        48679.965
#            Office Supplies  32762.115
#            Technology       59886.885
# 2014       Furniture        53025.240
#            Office Supplies  28441.020
#            Technology       70262.820
# 2015       Furniture        80984.250
#            Office Supplies  52410.195
#            Technology       71637.540

# %%
## profit in india

# %%
pd.pivot_table(sales_india, values='Profit', index=['Order_Year'], aggfunc=sum)
# Out:
#                Profit
# Order_Year
# 2012        19928.505
# 2013        27417.555
# 2014        32896.860
# 2015        48807.675

# %%
pd.pivot_table(sales_india, values='Profit', index=['Order_Year','Category'], aggfunc=sum)
# Out:
#                                Profit
# Order_Year Category
# 2012       Furniture         6494.085
#            Office Supplies   4445.265
#            Technology        8989.155
# 2013       Furniture         7950.705
#            Office Supplies   6894.435
#            Technology       12572.415
# 2014       Furniture         9348.480
#            Office Supplies   6821.400
#            Technology       16726.980
# 2015       Furniture        18641.760
#            Office Supplies  12361.815
#            Technology       17804.100

# %%
pd.pivot_table(sales_india, values='Profit', index=['Order_Year','Category','Sub_Category'], aggfunc=sum)
# Out:
#                                            Profit
# Order_Year Category        Sub_Category
# 2012       Furniture       Bookcases     3496.350
#                            Chairs        1613.625
#                            Furnishings   1045.650
#                            Tables         338.460
#            Office Supplies Appliances    1758.360
# ...                                           ...
# 2015       Office Supplies Supplies       960.420
#            Technology      Accessories   2147.310
#                            Copiers       6212.190
#                            Machines      2444.460
#                            Phones        7000.140
#
# [68 rows x 1 columns]

# %%
sales_india.State.unique()
# Out:
# array(['Gujarat', 'Haryana', 'Kerala', 'Jharkhand', 'Madhya Pradesh',
#        'Delhi', 'Uttarakhand', 'West Bengal', 'Bihar', 'Uttar Pradesh',
#        'Chhattisgarh', 'Tamil Nadu', 'Maharashtra', 'Karnataka',
#        'Rajasthan', 'Manipur', 'Andhra Pradesh', 'Jammu and Kashmir',
#        'Telangana', 'Punjab', 'Odisha', 'Puducherry', 'Assam',
#        'Chandigarh', 'Tripura'], dtype=object)

# %%
## state wise profit and sales india

# %%
pd.pivot_table(sales_india, values='Sales', index='State', aggfunc=sum)
# Out:
#                         Sales
# State
# Andhra Pradesh      19019.760
# Assam                5185.380
# Bihar               28615.140
# Chandigarh            491.940
# Chhattisgarh        22798.020
# Delhi               31026.030
# Gujarat             29290.350
# Haryana             24657.420
# Jammu and Kashmir    7969.080
# Jharkhand           12131.580
# Karnataka           31802.400
# Kerala              20696.970
# Madhya Pradesh      27069.780
# Maharashtra        101322.405
# Manipur              5429.340
# Odisha               5280.360
# Puducherry           2936.670
# Punjab              14007.720
# Rajasthan           30992.790
# Tamil Nadu          51911.460
# Telangana           15921.750
# Tripura               646.290
# Uttar Pradesh       76295.160
# Uttarakhand          7752.330
# West Bengal         16235.910

# %%
pd.pivot_table(sales_india, values='Profit', index='State', aggfunc=sum)
# Out:
#                       Profit
# State
# Andhra Pradesh      4565.490
# Assam                887.100
# Bihar               6139.080
# Chandigarh           193.950
# Chhattisgarh        6408.870
# Delhi               5568.720
# Gujarat             8090.760
# Haryana             6565.320
# Jammu and Kashmir   2844.240
# Jharkhand           4025.160
# Karnataka           9290.340
# Kerala              4773.960
# Madhya Pradesh      6268.020
# Maharashtra        16105.755
# Manipur              354.420
# Odisha              1395.960
# Puducherry           455.940
# Punjab              3035.550
# Rajasthan           7041.030
# Tamil Nadu          9992.400
# Telangana           3512.610
# Tripura              227.580
# Uttar Pradesh      17041.290
# Uttarakhand         1515.330
# West Bengal         2751.720

# %%
## findind sales in karnataka

# %%
sales_karnataka=sales_india[(sales_india['State']=='Karnataka')]

# %%
sales_karnataka
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship_Mode  \
# 408     27724  IN-2015-CY1274558-42300 2015-10-23 2015-10-25     First Class
# 782     27579  IN-2015-JW1522058-42101 2015-04-07 2015-04-12  Standard Class
# 1957    22906  IN-2014-RA1928558-41863 2014-08-12 2014-08-16  Standard Class
# 2364    28779  IN-2014-BO1135058-41783 2014-05-24 2014-05-30  Standard Class
# 2584    22907  IN-2014-RA1928558-41863 2014-08-12 2014-08-16  Standard Class
# ...       ...                      ...        ...        ...             ...
# 49208   20514  IN-2014-TC2129558-41676 2014-02-06 2014-02-11  Standard Class
# 49385   28815  IN-2015-MK1816058-42330 2015-11-22 2015-11-26  Standard Class
# 49749   23391  IN-2015-DR1294058-42294 2015-10-17 2015-10-18     First Class
# 50545   21375  IN-2015-MM1792058-42299 2015-10-22 2015-10-28  Standard Class
# 51176   23844  IN-2013-AR1057058-41441 2013-06-16 2013-06-21  Standard Class
#
# ...

# %%
pd.pivot_table(sales_karnataka, values='Sales', index='Country', aggfunc=sum)
# Out:
#            Sales
# Country
# India    31802.4

# %%
pd.pivot_table(sales_karnataka, values='Sales', index='Order_Year', aggfunc=sum)
# Out:
#                Sales
# Order_Year
# 2012         2430.72
# 2013         4622.28
# 2014        11077.68
# 2015        13671.72

# %%
pd.pivot_table(sales_karnataka, values='Sales', index=['Order_Year','Category'], aggfunc=sum)
# Out:
#                               Sales
# Order_Year Category
# 2012       Furniture         743.25
#            Office Supplies  1304.91
#            Technology        382.56
# 2013       Furniture        2103.81
#            Office Supplies  1139.31
#            Technology       1379.16
# 2014       Furniture        4787.52
#            Office Supplies  1918.11
#            Technology       4372.05
# 2015       Furniture        3058.62
#            Office Supplies  3414.18
#            Technology       7198.92

# %%
## Profit in karnataka

# %%
pd.pivot_table(sales_karnataka, values='Profit', index='Country', aggfunc=sum)
# Out:
#           Profit
# Country
# India    9290.34

# %%
pd.pivot_table(sales_karnataka, values='Profit', index='Order_Year', aggfunc=sum)
# Out:
#              Profit
# Order_Year
# 2012         672.84
# 2013        1051.44
# 2014        2855.73
# 2015        4710.33

# %%
pd.pivot_table(sales_karnataka, values='Profit', index=['Order_Year','Category'], aggfunc=sum)
# Out:
#                              Profit
# Order_Year Category
# 2012       Furniture         133.65
#            Office Supplies   470.55
#            Technology         68.64
# 2013       Furniture         263.46
#            Office Supplies   396.90
#            Technology        391.08
# 2014       Furniture        1406.25
#            Office Supplies   449.07
#            Technology       1000.41
# 2015       Furniture         798.36
#            Office Supplies   825.60
#            Technology       3086.37

# %%
sales_karnataka.City.unique()
# Out:
# array(['Bangalore', 'Mangalore', 'Tumkur', 'Belgaum', 'Hubli', 'Bijapur',
#        'Bellary', 'Gulbarga', 'Mysore', 'Shimoga'], dtype=object)

# %%
## finding sales in my city 'BELGAUM'

# %%
sales_belgaum=sales_india[sales_india['City']=='Belgaum']

# %%
sales_belgaum
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship_Mode  \
# 4564    23651  IN-2013-MG1769558-41620 2013-12-12 2013-12-18  Standard Class
# 5132    28511  IN-2012-AH1046558-41059 2012-05-30 2012-05-30        Same Day
# 8148    21018  IN-2014-KT1646558-41902 2014-09-20 2014-09-22     First Class
# 8944    25405  IN-2013-KD1634558-41452 2013-06-27 2013-07-02  Standard Class
# 12115   21017  IN-2014-KT1646558-41902 2014-09-20 2014-09-22     First Class
# 12250   21016  IN-2014-KT1646558-41902 2014-09-20 2014-09-22     First Class
# 21262   23649  IN-2013-MG1769558-41620 2013-12-12 2013-12-18  Standard Class
# 21761   28512  IN-2012-AH1046558-41059 2012-05-30 2012-05-30        Same Day
# 30037   25406  IN-2013-KD1634558-41452 2013-06-27 2013-07-02  Standard Class
# 31822   23650  IN-2013-MG1769558-41620 2013-12-12 2013-12-18  Standard Class
#
#       Customer ID     Customer Name   Segment     City      State  ...  \
# ...

# %%
sales_belgaum.rename({'Ship Mode':'Ship_Mode'},axis=1,inplace=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
sales_belgaum
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship_Mode  \
# 4564    23651  IN-2013-MG1769558-41620 2013-12-12 2013-12-18  Standard Class
# 5132    28511  IN-2012-AH1046558-41059 2012-05-30 2012-05-30        Same Day
# 8148    21018  IN-2014-KT1646558-41902 2014-09-20 2014-09-22     First Class
# 8944    25405  IN-2013-KD1634558-41452 2013-06-27 2013-07-02  Standard Class
# 12115   21017  IN-2014-KT1646558-41902 2014-09-20 2014-09-22     First Class
# 12250   21016  IN-2014-KT1646558-41902 2014-09-20 2014-09-22     First Class
# 21262   23649  IN-2013-MG1769558-41620 2013-12-12 2013-12-18  Standard Class
# 21761   28512  IN-2012-AH1046558-41059 2012-05-30 2012-05-30        Same Day
# 30037   25406  IN-2013-KD1634558-41452 2013-06-27 2013-07-02  Standard Class
# 31822   23650  IN-2013-MG1769558-41620 2013-12-12 2013-12-18  Standard Class
#
#       Customer ID     Customer Name   Segment     City      State  ...  \
# ...

# %%
sales_belgaum.value_counts('Ship_Mode')
# Out:
# Ship_Mode
# Standard Class    5
# First Class       3
# Same Day          2
# dtype: int64

# %%
pd.pivot_table(sales_belgaum, values='Sales', index='City', aggfunc=sum)
# Out:
#            Sales
# City
# Belgaum  3478.26

# %%
pd.pivot_table(sales_belgaum, values='Sales', index='Order_Year', aggfunc=sum)
# Out:
#               Sales
# Order_Year
# 2012         521.25
# 2013        2295.36
# 2014         661.65

# %%
pd.pivot_table(sales_belgaum, values='Sales', index=['Order_Year','Category'], aggfunc=sum)
# Out:
#                               Sales
# Order_Year Category
# 2012       Office Supplies   138.69
#            Technology        382.56
# 2013       Furniture        1601.28
#            Office Supplies   694.08
# 2014       Furniture         661.65

# %%
## profit in belgaum

# %%
pd.pivot_table(sales_belgaum, values='Profit', index='City', aggfunc=sum)
# Out:
#          Profit
# City
# Belgaum  755.49

# %%
pd.pivot_table(sales_belgaum, values='Profit', index='Order_Year', aggfunc=sum)
# Out:
#             Profit
# Order_Year
# 2012        119.94
# 2013        425.25
# 2014        210.30

# %%
pd.pivot_table(sales_belgaum, values='Profit', index=['Order_Year','Category'], aggfunc=sum)
# Out:
#                             Profit
# Order_Year Category
# 2012       Office Supplies   51.30
#            Technology        68.64
# 2013       Furniture        202.68
#            Office Supplies  222.57
# 2014       Furniture        210.30

# %%
## total shipping cost collected in belgau city

# %%
pd.pivot_table(sales_belgaum, values='Shipping Cost', index='City', aggfunc=sum)
# Out:
#          Shipping Cost
# City
# Belgaum         300.62

# %%
## minimum and maximum shipping cost

# %%
pd.pivot_table(sales_belgaum, values='Shipping Cost', index='City', aggfunc=min)
# Out:
#          Shipping Cost
# City
# Belgaum           4.72

# %%
pd.pivot_table(sales_belgaum, values='Shipping Cost', index='City', aggfunc=max)
# Out:
#          Shipping Cost
# City
# Belgaum          72.14

# %%
## which Category has maximum shipping cost

# %%
pd.pivot_table(sales_belgaum, values='Shipping Cost', index='Category', aggfunc=max)
# Out:
#                  Shipping Cost
# Category
# Furniture                72.14
# Office Supplies          11.19
# Technology               65.04

# %%
## Quantity of product ordered

# %%
pd.pivot_table(sales_belgaum, values='Quantity', index='Product Name', aggfunc=sum)
# Out:
#                                        Quantity
# Product Name
# BIC Highlighters, Water Color                 2
# Cameo Interoffice Envelope, Recycled          3
# Fellowes File Cart, Single Width              3
# Hon Chairmat, Black                           3
# Ikea 3-Shelf Cabinet, Metal                   3
# Logitech Numeric Keypad, Programmable         8
# Rubbermaid Clock, Black                       5
# SanDisk Note Cards, 8.5 x 11                  8
# Sauder Floating Shelf Set, Pine               6
# Tenex Clock, Duo Pack                         5

# %%
pd.pivot_table(sales_belgaum, values=['Profit','Sales','Quantity'], index='Product Name', aggfunc=sum)
# Out:
#                                        Profit  Quantity    Sales
# Product Name
# BIC Highlighters, Water Color            0.00         2    44.22
# Cameo Interoffice Envelope, Recycled    51.30         3   138.69
# Fellowes File Cart, Single Width       206.01         3   412.02
# Hon Chairmat, Black                     27.00         3   159.30
# Ikea 3-Shelf Cabinet, Metal             85.14         3   425.70
# Logitech Numeric Keypad, Programmable   68.64         8   382.56
# Rubbermaid Clock, Black                 85.20         5   250.80
# SanDisk Note Cards, 8.5 x 11            16.56         8   237.84
# Sauder Floating Shelf Set, Pine        117.54         6  1175.58
# Tenex Clock, Duo Pack                   98.10         5   251.55

# %%
pd.pivot_table(sales_belgaum, values=['Quantity','Sales','Profit','Discount'], index='Product Name', aggfunc=sum)
# Out:
#                                        Discount  Profit  Quantity    Sales
# Product Name
# BIC Highlighters, Water Color               0.0    0.00         2    44.22
# Cameo Interoffice Envelope, Recycled        0.0   51.30         3   138.69
# Fellowes File Cart, Single Width            0.0  206.01         3   412.02
# Hon Chairmat, Black                         0.0   27.00         3   159.30
# Ikea 3-Shelf Cabinet, Metal                 0.0   85.14         3   425.70
# Logitech Numeric Keypad, Programmable       0.0   68.64         8   382.56
# Rubbermaid Clock, Black                     0.0   85.20         5   250.80
# SanDisk Note Cards, 8.5 x 11                0.0   16.56         8   237.84
# Sauder Floating Shelf Set, Pine             0.0  117.54         6  1175.58
# Tenex Clock, Duo Pack                       0.0   98.10         5   251.55

# %%
## online selling companies bill sheet

# %%
pd.pivot_table(sales_belgaum, values=['Quantity','Sales','Shipping Cost'], index=['Customer Name','Product Name','Ship_Mode'], aggfunc=sum)
# Out:
#                                                                        Quantity  \
# Customer Name    Product Name                          Ship_Mode
# Amy Hunt         Cameo Interoffice Envelope, Recycled  Same Day               3
#                  Logitech Numeric Keypad, Programmable Same Day               8
# Katherine Ducich BIC Highlighters, Water Color         Standard Class         2
#                  Ikea 3-Shelf Cabinet, Metal           Standard Class         3
# Kean Takahito    Hon Chairmat, Black                   First Class            3
#                  Rubbermaid Clock, Black               First Class            5
#                  Tenex Clock, Duo Pack                 First Class            5
# Maureen Gnade    Fellowes File Cart, Single Width      Standard Class         3
#                  SanDisk Note Cards, 8.5 x 11          Standard Class         8
#                  Sauder Floating Shelf Set, Pine       Standard Class         6
#
# ...

# %%
store=pd.read_excel('D:\\PGP IN DATA SCIENCE\\Files\\Global_Superstore.xlsx')

# %%
store
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
store.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Profit Category-Updated', 'Profit Category', 'Shipping Cost',
#        'Order Priority'],
#       dtype='object')

# %%
store.drop(['Postal Code'], axis=1, inplace=True)

# %%
store
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
store.rename({'Profit Category':'Profit_Category'}, axis=1, inplace=True)

# %%
store
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
store.Profit_Category.unique()
# Out:
# array(['Awesome', 'Worse', 'Good'], dtype=object)

# %%
store_pro_worse=store[store['Profit_Category']=='Worse']

# %%
store_pro_worse
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
store_pro_good=store[store['Profit_Category']=='Good']

# %%
store_pro_good
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 13       4132   MX-2013-VF2171518-41591 2013-11-13 2013-11-13        Same Day
# 15      13779   ES-2015-BP1118545-42216 2015-07-31 2015-08-03    Second Class
# 24       1570   US-2015-NP1832582-42216 2015-07-31 2015-08-01     First Class
# 28      38460  CA-2012-AH10030140-41020 2012-04-21 2012-04-23    Second Class
# 36      36651  CA-2012-AH10030140-41041 2012-05-12 2012-05-18  Standard Class
# ...       ...                       ...        ...        ...             ...
# 45139   36731  CA-2013-RM19675140-41566 2013-10-19 2013-10-24  Standard Class
# 47673   18137  IT-2012-RE19405139-40982 2012-03-14 2012-03-14        Same Day
# 48351    2640   MX-2013-TS2134082-41443 2013-06-18 2013-06-20    Second Class
# 48571   31053   IN-2014-PF1922592-41982 2014-12-09 2014-12-15  Standard Class
# 49896   32789  CA-2015-TS21370140-42333 2015-11-25 2015-11-29  Standard Class
#
# ...

# %%
store_pro_awesome=store[store['Profit_Category']=='Awesome']

# %%
store_pro_awesome
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 18      22096    IN-2015-JS156857-42035 2015-01-31 2015-02-01     First Class
# 43      16681  ES-2013-GT14710139-41621 2013-12-13 2013-12-17  Standard Class
# 82      40834  CA-2014-AS10045140-41908 2014-09-26 2014-09-28     First Class
# 193     39745  CA-2015-AH10075140-42301 2015-10-24 2015-10-25     First Class
# 216     11073  ES-2014-SC20305120-41909 2014-09-27 2014-09-27        Same Day
# 314     14952   ES-2014-CD1279048-41899 2014-09-17 2014-09-20     First Class
# 335     13571  IT-2012-PC19000120-41004 2012-04-05 2012-04-07     First Class
# 420     29593   IN-2015-MO1780066-42308 2015-10-31 2015-11-04  Standard Class
# 642     29782   IN-2014-DK1289559-41697 2014-02-27 2014-03-04  Standard Class
# 2258    38757  US-2013-AR10540140-41375 2013-04-11 2013-04-14    Second Class
# ...

# %%
## whether the business earning high profit

# %%
store_pro_worse.value_counts('Profit_Category')
# Out:
# Profit_Category
# Worse    51142
# dtype: int64

# %%
store_pro_good.value_counts('Profit_Category')
# Out:
# Profit_Category
# Good    122
# dtype: int64

# %%
store_pro_awesome.value_counts('Profit_Category')
# Out:
# Profit_Category
# Awesome    26
# dtype: int64

# %%
Look like business not earning good profit

# %%
## Updated profit category

# %%
store.rename({'Profit Category-Updated':'Profit_Category_Updated'}, axis=1, inplace=True)

# %%
store
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
store.Profit_Category_Updated.unique()
# Out:
# array(['Worse', 'Good'], dtype=object)

# %%
store.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Region', 'Market', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Profit_Category_Updated', 'Profit_Category', 'Shipping Cost',
#        'Order Priority'],
#       dtype='object')

# %%
store_prof_upd_worse=store[store['Profit_Category_Updated']=='Worse']

# %%
store_prof_upd_good=store[store['Profit_Category_Updated']=='Good']

# %%
store_prof_upd_worse
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
store_prof_upd_good
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 12      45794   SA-2012-MM7260110-41269 2012-12-26 2012-12-28    Second Class
# 14      27704   IN-2014-PF1912027-41796 2014-06-06 2014-06-08    Second Class
# 17      12069   ES-2015-PJ1883564-42255 2015-09-08 2015-09-14  Standard Class
# 23      13528  ES-2014-LB16795139-41697 2014-02-27 2014-03-01    Second Class
# 27      11645   ES-2012-EB1411048-40981 2012-03-13 2012-03-16    Second Class
# ...       ...                       ...        ...        ...             ...
# 48570   46366   CA-2015-SV1081523-42361 2015-12-23 2015-12-25    Second Class
# 49003   38123  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 49895   37637  CA-2015-TS21370140-42283 2015-10-06 2015-10-10  Standard Class
# 49940   33920  CA-2015-TA21385140-42300 2015-10-23 2015-10-25     First Class
# 49968   37923  CA-2012-TB21400140-41256 2012-12-13 2012-12-20  Standard Class
#
# ...

# %%
store_prof_upd_worse.value_counts('Profit_Category_Updated')
# Out:
# Profit_Category_Updated
# Worse    51143
# dtype: int64

# %%
store_prof_upd_good.value_counts('Profit_Category_Updated')
# Out:
# Profit_Category_Updated
# Good    147
# dtype: int64

# %%
##How many Apple iphone 5S sold, sales, profit, shipping cost

# %%
store['Year']=store['Order Date'].dt.year

# %%
store
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
iphone_5S=store[store['Product Name']=='Apple iPhone 5S']

# %%
iphone_5S
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 31821   39224  CA-2015-KH16330140-42329 2015-11-21 2015-11-25    Second Class
# 34135   35134  CA-2012-KM16720140-41115 2012-07-25 2012-08-01  Standard Class
# 44958   37228  US-2015-RL19615140-42193 2015-07-08 2015-07-10     First Class
# 48607   31784  CA-2012-SA20830140-41210 2012-10-28 2012-10-30     First Class
#
#         Customer ID    Customer Name    Segment  Postal Code             City  \
# 31821  KH-163301406  Katharine Harms  Corporate      10035.0    New York City
# 34135  KM-167201404     Kunst Miller   Consumer      89031.0  North Las Vegas
# 44958  RL-196151406        Rob Lucas   Consumer      19120.0     Philadelphia
# 48607  SA-208301402     Sue Ann Reed   Consumer      60610.0          Chicago
#
#        ...     Product Name     Sales Quantity Discount   Profit  \
# 31821  ...  Apple iPhone 5S   569.990        1      0.0  170.997
# ...

# %%
store
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
## How many different varieties of phones available to sale

# %%
phones=store[store['Sub-Category']=='Phones']

# %%
phones
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# 12      45794   SA-2012-MM7260110-41269 2012-12-26 2012-12-28    Second Class
# ...       ...                       ...        ...        ...             ...
# 51200   32343  CA-2014-ZC21910140-41707 2014-03-09 2014-03-14  Standard Class
# 51216   31885  US-2014-ZC21910140-41719 2014-03-21 2014-03-25  Standard Class
# 51261   35111  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09        Same Day
# 51262   31316  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51265   37195  CA-2014-ZD21925140-41733 2014-04-04 2014-04-10  Standard Class
#
# ...

# %%
phones.rename({'Product Name':'Product_Name'}, axis=1, inplace=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
phones
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# 12      45794   SA-2012-MM7260110-41269 2012-12-26 2012-12-28    Second Class
# ...       ...                       ...        ...        ...             ...
# 51200   32343  CA-2014-ZC21910140-41707 2014-03-09 2014-03-14  Standard Class
# 51216   31885  US-2014-ZC21910140-41719 2014-03-21 2014-03-25  Standard Class
# 51261   35111  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09        Same Day
# 51262   31316  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51265   37195  CA-2014-ZD21925140-41733 2014-04-04 2014-04-10  Standard Class
#
# ...

# %%
phones.Product_Name.nunique()
# Out:
# 305

# %%
## which phone is costlier

# %%
pd.pivot_table(phones, values='Sales', index='Product_Name', aggfunc=max)
# Out:
#                                                       Sales
# Product_Name
# ARKON Windshield Dashboard Air Vent Car Mount H...   67.800
# AT&T 1070 Corded Phone                              445.960
# AT&T 1080 Corded phone                              438.368
# AT&T 1080 Phone                                     821.940
# AT&T 17929 Lendline Telephone                       226.200
# ...                                                     ...
# iKross Bluetooth Portable Keyboard + Cell Phone...  209.500
# iOttie HLCRIO102 Car Mount                          119.940
# iOttie XL Car Mount                                 143.928
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...   89.950
# netTALK DUO VoIP Telephone Service                  377.928
#
# [305 rows x 1 columns]

# %%
## Total profit and sale collected by selling phone

# %%
pd.pivot_table(phones, values=['Sales','Profit'], index='Sub-Category', aggfunc=sum)
# Out:
#                    Profit         Sales
# Sub-Category
# Phones        216717.0058  1.706824e+06

# %%
## varieties of phones sold in india & their profit

# %%
phones_india=phones[phones['Country']=='India']

# %%
phones_india
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 41      29272  IN-2015-BF1100558-42319 2015-11-11 2015-11-15  Standard Class
# 90      29600  IN-2013-GP1474058-41419 2013-05-25 2013-05-28    Second Class
# 224     26325  IN-2015-AP1072058-42284 2015-10-07 2015-10-11  Standard Class
# 225     21924  IN-2015-CR1282058-42294 2015-10-17 2015-10-21  Standard Class
# 313     23212  IN-2014-CA1277558-41802 2014-06-12 2014-06-17  Standard Class
# ...       ...                      ...        ...        ...             ...
# 28766   26623  IN-2014-IM1507058-41812 2014-06-22 2014-06-27  Standard Class
# 30184   27452  IN-2014-KB1658558-41994 2014-12-21 2014-12-26  Standard Class
# 33030   23245  IN-2015-DW1358558-42301 2015-10-24 2015-10-28  Standard Class
# 35903   27290  IN-2013-JS1568558-41371 2013-04-07 2013-04-12  Standard Class
# 42345   21930  IN-2015-CR1282058-42294 2015-10-17 2015-10-21  Standard Class
#
# ...

# %%
pd.pivot_table(phones_india, values=['Sales', 'Profit'], index='Sub-Category', aggfunc=sum)
# Out:
#                  Profit       Sales
# Sub-Category
# Phones        23279.475  104627.235

# %%
phones_india.Product_Name.nunique()
# Out:
# 78
